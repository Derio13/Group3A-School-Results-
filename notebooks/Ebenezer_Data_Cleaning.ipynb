# %% [raw]
# import  pandas as pd
# import numpy as np

# %%
import subprocess
subprocess.check_call(['pip', 'install', 'psycopg2-binary'])

# %%
import pandas as pd
import numpy as np
# Database connection
host = 'internship-db.coh86gwewtxb.us-east-1.rds.amazonaws.com'
port = 5432
database = 'internship'
user = 'group3a'
password = '9pF7Sk0MjyVPgLjoEWCI'

# Connect and load raw data
import psycopg2
conn = psycopg2.connect(host=host, port=port, database=database, user=user, password=password, sslmode='require')

df_raw = pd.read_sql('SELECT * FROM raw_school.results', conn)
print(f"Loaded {len(df_raw)} rows")
df_raw.head()
# Out:
# C:\Users\12345\AppData\Local\Temp\ipykernel_12964\3010736176.py:14: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_raw = pd.read_sql('SELECT * FROM raw_school.results', conn)
# Loaded 30120 rows
#    result_id   exam_date  student_id  subject_id  teacher_id       term  \
# 0       5286  2024-01-05         633           9          44     Term 1
# 1      11177  18/05/2025         421           9          50    Term 2
# 2      10157  2024-05-04         222           3          22     Term 3
# 3      16448  2025-06-21         961          10          42     Term 3
# 4      29013  2025-09-29         190           9          23     Term 3
#
#    score  attendance_pct
# 0    NaN            75.1
# 1   57.1            94.4
# 2   48.9            83.2
# 3   41.5            94.4
# 4   27.2            94.4
